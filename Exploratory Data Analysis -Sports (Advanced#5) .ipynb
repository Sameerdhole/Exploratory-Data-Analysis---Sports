# %% [markdown]
# # Exploratory Data Analysis - Sports
# # Sameer Dhole
# # #GRIPFEB21

# %%
import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import dask.dataframe as dd

# %%
df=pd.read_csv(r"C:\Users\dhole\Downloads\Indian Premier League\deliveries.csv",encoding='latin1',dtype='unicode',low_memory=False)

# %%
df
# Out:
#        match_id inning         batting_team                 bowling_team over  \
# 0             1      1  Sunrisers Hyderabad  Royal Challengers Bangalore    1
# 1             1      1  Sunrisers Hyderabad  Royal Challengers Bangalore    1
# 2             1      1  Sunrisers Hyderabad  Royal Challengers Bangalore    1
# 3             1      1  Sunrisers Hyderabad  Royal Challengers Bangalore    1
# 4             1      1  Sunrisers Hyderabad  Royal Challengers Bangalore    1
# ...         ...    ...                  ...                          ...  ...
# 179073    11415      2  Chennai Super Kings               Mumbai Indians   20
# 179074    11415      2  Chennai Super Kings               Mumbai Indians   20
# 179075    11415      2  Chennai Super Kings               Mumbai Indians   20
# 179076    11415      2  Chennai Super Kings               Mumbai Indians   20
# 179077    11415      2  Chennai Super Kings               Mumbai Indians   20
#
# ...

# %%
df.shape
# Out:
# (179078, 21)

# %%
ff=pd.read_csv(r"C:\Users\dhole\Downloads\Indian Premier League\matches.csv",encoding='latin1',dtype='unicode',low_memory=False)

# %%
ff.shape
# Out:
# (756, 18)

# %%
ff.head()
# Out:
#   id season       city        date                        team1  \
# 0  1   2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1  2   2017       Pune  2017-04-06               Mumbai Indians
# 2  3   2017     Rajkot  2017-04-07                Gujarat Lions
# 3  4   2017     Indore  2017-04-08       Rising Pune Supergiant
# 4  5   2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result dl_applied                       winner win_by_runs win_by_wickets  \
# ...

# %%
print(ff['winner'].value_counts())
plt.figure(figsize=(15,8))
sns.countplot(x=ff['winner'])
plt.xticks(rotation=90)
plt.show()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Delhi Capitals                  10
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %% [markdown]
# # Most successful team is Mumbai Indians

# %%
df=df.replace(np.nan, 0)

# %%
df
# Out:
#        match_id inning         batting_team                 bowling_team over  \
# 0             1      1  Sunrisers Hyderabad  Royal Challengers Bangalore    1
# 1             1      1  Sunrisers Hyderabad  Royal Challengers Bangalore    1
# 2             1      1  Sunrisers Hyderabad  Royal Challengers Bangalore    1
# 3             1      1  Sunrisers Hyderabad  Royal Challengers Bangalore    1
# 4             1      1  Sunrisers Hyderabad  Royal Challengers Bangalore    1
# ...         ...    ...                  ...                          ...  ...
# 179073    11415      2  Chennai Super Kings               Mumbai Indians   20
# 179074    11415      2  Chennai Super Kings               Mumbai Indians   20
# 179075    11415      2  Chennai Super Kings               Mumbai Indians   20
# 179076    11415      2  Chennai Super Kings               Mumbai Indians   20
# 179077    11415      2  Chennai Super Kings               Mumbai Indians   20
#
# ...

# %%
print(ff['player_of_match'].value_counts())
plt.figure(figsize=(35,18))
sns.countplot(x=ff['player_of_match'])
plt.xticks(rotation=90)
plt.show()
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# DA Warner         17
# MS Dhoni          17
#                   ..
# J Botha            1
# JJ Roy             1
# KK Cooper          1
# TM Dilshan         1
# S Curran           1
# Name: player_of_match, Length: 226, dtype: int64

# %% [markdown]
# # Most Man of the Match won by Chris Gayle

# %%
plt.figure(figsize=(18,100))
sns.countplot(y='batsman',hue='total_runs', data=df, palette="Greens_d")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Best Batsman is Virat Kohli

# %%
print(ff['toss_winner'].value_counts())
plt.figure(figsize=(35,18))
sns.countplot(x=ff['toss_winner'])
plt.xticks(rotation=90)
plt.show()
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Kings XI Punjab                81
# Royal Challengers Bangalore    81
# Rajasthan Royals               80
# Delhi Daredevils               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
plt.figure(figsize=(35,18))
sns.countplot(x='toss_winner',hue='toss_decision', data=ff, palette="Greens_d")
plt.xticks(rotation=90)
plt.show()

# %%
print(ff['toss_decision'].value_counts())
plt.figure(figsize=(15,8))
sns.countplot(x=ff['toss_decision'])
plt.xticks(rotation=90)
plt.show()
# Out:
# field    463
# bat      293
# Name: toss_decision, dtype: int64

# %% [markdown]
# # According to Analysis companies should sponsor the
# Best team : Mumbai Indians
# Best player :Chris Gayle
# Best batsman:Virat Kohli

# %% [markdown]
# # Selecting Field after toss is a mojor factor contributing to wins

# %%
r
